# %% [markdown]
# In visual studio, we have several languages including python
#
# However, we need to install libraries to use the codes in python (instructions)
#
# 1. Pandas- import datasets in different formats
# 2. Numpy-structures data

# %%
#Installing a library for data importation
#Library is called pandas
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Some of the libraries have very long names, so when importing we shorten the names
#
# E.g. scikitlearn is too long sci, skt

# %%
#Have to import library to use its codes
#And import it as short-form name "pd"
import pandas as pd

# %%
#Import my dataset called Bike_sales
pd.read_excel("Bike_Sales.xlsx")
# Out:
#              Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0      2017-01-01    1   January  2017            17           Youth (<25)
# 1      2017-01-01    1   January  2017            23           Youth (<25)
# 2      2017-01-01    1   January  2017            33  Young Adults (25-34)
# 3      2017-01-01    1   January  2017            39        Adults (35-64)
# 4      2017-01-01    1   January  2017            42        Adults (35-64)
# ...           ...  ...       ...   ...           ...                   ...
# 113031 2021-12-31   31  December  2021            52        Adults (35-64)
# 113032 2021-12-31   31  December  2021            25  Young Adults (25-34)
# 113033 2021-12-31   31  December  2021            26  Young Adults (25-34)
# 113034 2021-12-31   31  December  2021            33  Young Adults (25-34)
# 113035 2021-12-31   31  December  2021            44        Adults (35-64)
#
# ...

# %%
#turn dataset in to a pandas dataframe
#We can call the dataframe any name e.g. "data"
data=pd.read_excel("Bike_Sales.xlsx")

# %%
#View dataframe
data
# Out:
#              Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0      2017-01-01    1   January  2017            17           Youth (<25)
# 1      2017-01-01    1   January  2017            23           Youth (<25)
# 2      2017-01-01    1   January  2017            33  Young Adults (25-34)
# 3      2017-01-01    1   January  2017            39        Adults (35-64)
# 4      2017-01-01    1   January  2017            42        Adults (35-64)
# ...           ...  ...       ...   ...           ...                   ...
# 113031 2021-12-31   31  December  2021            52        Adults (35-64)
# 113032 2021-12-31   31  December  2021            25  Young Adults (25-34)
# 113033 2021-12-31   31  December  2021            26  Young Adults (25-34)
# 113034 2021-12-31   31  December  2021            33  Young Adults (25-34)
# 113035 2021-12-31   31  December  2021            44        Adults (35-64)
#
# ...

# %% [markdown]
# Data Exploration

# %%
#Main information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
data.dtypes
# Out:
# Date                datetime64[ns]
# Day                          int64
# Month                       object
# Year                         int64
# Customer_Age                 int64
# Age_Group                   object
# Customer_Gender             object
# Country                     object
# State                       object
# Product_Category            object
# Sub_Category                object
# Product                     object
# Order_Quantity               int64
# Unit_Cost                    int64
# Unit_Price                   int64
# Profit                       int64
# Cost                         int64
# Revenue                      int64
# dtype: object

# %%
#Checking the descriptive statistics (Central tendency, Variability)
data.describe()
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2020-01-06 01:36:09.376127744      15.665753    2019.520153
# min              2017-01-01 00:00:00       1.000000    2017.000000
# 25%              2019-01-09 00:00:00       8.000000    2019.000000
# 50%              2019-10-16 00:00:00      16.000000    2019.500000
# 75%              2021-01-28 00:00:00      23.000000    2021.000000
# max              2021-12-31 00:00:00      31.000000    2021.000000
# std                              NaN       8.781567       1.179704
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %% [markdown]
# Comments: For each variable regarding Central Tendency and Variability

# %%
#Or check the descriptive statistics of just one variable in the dataset
#Looking at a particular descriptive statistic e.g. median
data["Profit"].describe()
# Out:
# count    113036.000000
# mean        372.681358
# std         595.080571
# min           1.000000
# 25%          39.000000
# 50%         135.000000
# 75%         432.000000
# max       26158.000000
# Name: Profit, dtype: float64

# %% [markdown]
# The mean of Profit is way greater than the median implying the variable is positively skewed.
#
# Further analyses need to be run to check for outliers and transform the variable

# %%
#To calculate the descriptive stats of the categorical/object variables
import numpy as np
data.describe(include=object)
# Out:
#          Month       Age_Group Customer_Gender        Country       State  \
# count   113036          113036          113036         113036      113036
# unique      12               4               2              6          53
# top       June  Adults (35-64)               M  United States  California
# freq     11234           55824           58312          39206       22450
#
#        Product_Category     Sub_Category                Product
# count            113036           113036                 113036
# unique                3               17                    130
# top         Accessories  Tires and Tubes  Water Bottle - 30 oz.
# freq              70120            33870                  10794
